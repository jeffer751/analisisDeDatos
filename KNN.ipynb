# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#Cargar los datos
data = pd.read_csv("C:/Users/Stella Cuero/OneDrive/Escritorio/STEVEN/universidad/Analisis de datos/UNIDAD 4/Cleaned-Data.csv", sep=",")

# %%
# conjunto de datos
data = data[['Dry-Cough', 'Difficulty-in-Breathing', 'Sore-Throat', 'None_Sympton', 'Pains', 'Nasal-Congestion', 'Runny-Nose', 'Diarrhea']]
target = data['None_Sympton']

# %%
#histograma
data.hist()
plt.show()

# %%
#predicision
data.boxplot()
plt.show()

# %%
#Correlacion
print(data.corr())
# Out:
#                             Dry-Cough  Difficulty-in-Breathing   Sore-Throat  \
# Dry-Cough                1.000000e+00             3.779645e-01  5.096472e-02
# Difficulty-in-Breathing  3.779645e-01             1.000000e+00  4.045199e-01
# Sore-Throat              5.096472e-02             4.045199e-01  1.000000e+00
# None_Sympton            -2.927700e-01            -2.581989e-01 -1.740777e-01
# Pains                    4.519459e-18            -9.663757e-19 -1.063529e-17
# Nasal-Congestion        -5.180861e-17             1.076763e-17  3.705775e-17
# Runny-Nose              -9.767619e-17            -1.091121e-17  2.844633e-17
# Diarrhea                -1.403602e-17             1.067239e-17  1.819491e-17
#
#                          None_Sympton         Pains  Nasal-Congestion  \
# Dry-Cough               -2.927700e-01  4.519459e-18     -5.180861e-17
# Difficulty-in-Breathing -2.581989e-01 -9.663757e-19      1.076763e-17
# ...
