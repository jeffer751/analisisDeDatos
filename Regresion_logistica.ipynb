# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
import numpy as np
import pandas as pd
import os

# %%
#Cargar los datos
data = pd.read_csv("C:/Users/Stella Cuero/OneDrive/Escritorio/STEVEN/universidad/Analisis de datos/UNIDAD 2/Regresion_logistica/framingham.csv", sep=",")

# %%
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
Data[['totChol','diabetes']].head()
# Out:
#    totChol  diabetes
# 0    195.0         0
# 1    250.0         0
# 2    245.0         0
# 3    225.0         0
# 4    285.0         0

# %%
data[['totChol','diabetes']].plot.scatter(x='totChol',y='diabetes')
# Out:
# <Axes: xlabel='totChol', ylabel='diabetes'>

# %%
# pruebas de parametro
w = 0.09
b = -3.6

# %%
x = np.linspace(0,Data['totChol'].max(),100)
y = 1/(1+np.exp(-(w*x+b)))

#graficos
Data.plot.scatter(x='totChol',y='diabetes')
plt.plot(x, y, '-r')
plt.ylim(0,Data['diabetes'].max()*1.1)
plt.scatter(x, y, color='orange')
# plt.grid()
plt.show()
